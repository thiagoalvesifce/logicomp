# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/IFCE/2024.1/lcomp/logicomp-master/main.py
# Out:
# False
# False
# True
# formula1: p
# formula2: q
# formula3: (p ∧ q)
# formula4: (p ∧ s)
# formula5: (¬(p ∧ s))
# formula6: ((¬(p ∧ s)) ∨ q)
# formula7: ((¬(p ∧ s)) → (q ∧ r))
# formula8: ((¬(p ∧ s)) → (q ∧ (¬(p ∧ s))))
# length of formula1: 1
# length of formula3: 3
# length of formula7: 8
# subformulas of formula7:
# {<formula.Atom object at 0x7ce8206670a0>, <formula.And object at 0x7ce820667100>, <formula.Atom object at 0x7ce820666f20>, <formula.Atom object at 0x7ce820666e90>, <formula.Implies object at 0x7ce820667160>, <formula.Atom object at 0x7ce820667040>, <formula.Not object at 0x7ce820666fe0>, <formula.And object at 0x7ce820666f80>}
# r
# (q ∧ r)
# s
# p
# ((¬(p ∧ s)) → (q ∧ r))
# q
# (¬(p ∧ s))
# (p ∧ s)
# length of formula8: 11
# subformulas of formula8:
# s
# p
# q
# (q ∧ (¬(p ∧ s)))
# (¬(p ∧ s))
# (p ∧ s)
# ((¬(p ∧ s)) → (q ∧ (¬(p ∧ s))))
# number of subformulas of formula8: 7
# len(subformulas(formula8)) <= length(formula8): True
